# %% [markdown]
# **THE DATASET MNIST CAN BE FOUND**: http://yann.lecun.com

# %%
# Import libraries
import os
import time
import numpy as np
import random
import matplotlib.pyplot as plt
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchsummary import summary

# %%
# Set seed for the project 
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed = 42
set_seed(seed)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# Data root
ROOT = './data'

# Train data
train_data = datasets.MNIST(
    root = ROOT,
    train = True,
    download = True
)

# Test data
test_data = datasets.MNIST(
    root = ROOT,
    train = False,
    download = True
)

# %% [markdown]
# **PREPROCESSING DATA**

# %%
# We split the training and validation with the ration 0.9:0.1
valid_ratio = 0.9

n_train_examples = int(len(train_data) * valid_ratio)
n_valid_examples = len(train_data) - n_train_examples

train_data, valid_data = data.random_split(
    train_data,
    [n_train_examples, n_valid_examples]
)

# %%
# We need to normalize the image by mean and standard deviation
def normalization(df):
    m = df.dataset.data.float().mean()/255
    s = df.dataset.data.float().std()/255
    return m, s

mean, std = normalization(train_data)

train_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean = [mean], std = [std])
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean = [mean], std = [std])
])

train_data.dataset.transform = train_transforms
valid_data.dataset.transform = test_transforms

# %% [markdown]
# **CREATE DATALOADER**

# %%
batch_size = 256

# Training dataloader
train_dataloader = data.DataLoader(
    train_data,
    shuffle = True,
    batch_size = batch_size
)

# Validation dataloader
valid_dataloader = data.DataLoader(
    valid_data,
    batch_size = batch_size
)

# %% [markdown]
# **ALEXNET MODEL**

# %%
class AlexNetCls(nn.Module):
    def __init__(self, num_classes): 
        super(AlexNetCls, self).__init__()
        self.features = nn.Sequential(
            # For MNIST, only one color is available - gray scale (1 channel)
            # Convolutional Layer 1
            nn.Conv2d(in_channels = 1, out_channels = 32, kernel_size=3, padding=1), 
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), 
            nn.BatchNorm2d(32),

            # Convolutional Layer 2
            nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size=3, padding=1), 
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), 
            nn.BatchNorm2d(64),

            # Convolutional Layer 3
            nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size=3, padding=1), 
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),

            # Convolutional Layer 4
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size=3, padding=1), 
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),

            # Convolutional Layer 5
            nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size=3, padding=1), 
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), 
            nn.BatchNorm2d(64),
        )

        self.avgpool = nn.AdaptiveAvgPool2d((3, 3)) 
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(64 * 3 * 3, 512), 
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(512),

            nn.Dropout(),
            nn.Linear(512, 512), 
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(512),

            nn.Linear(512, num_classes) 
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %% [markdown]
# **TRAINING THE MODEL**

# %%
# Training function
def train(
    model, optimizer, criterion, train_dataloader,
    device, epoch = 0, log_interval = 50
):
    model.train()
    total_acc, total_count = 0, 0
    losses = []
    start_time = time.time()
    
    for idx, (inputs, labels) in enumerate(train_dataloader):
        inputs = inputs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        
        # Predict the outputs
        predictions = model(inputs)
        
        # Compute loss using the criterion
        loss = criterion(predictions, labels)
        losses.append(loss.item())
        
        # Backward
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predictions.argmax(1) == labels).sum().item()
        total_count += labels.size(0)

        # Printing details
        if idx%log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print(
                '| epoch {:3d} | {:5d}/{:5d} batches '
                '| accuracy {:8.3f}'.format(
                    epoch, idx, len(train_dataloader), total_acc/total_count
                )
            )
            total_acc, total_count = 0, 0
            start_time = time.time()
    
    # Compute epoch accuracy and epoch loss
    epoch_acc = total_acc/total_count
    epoch_loss = sum(losses)/len(losses)
    return epoch_acc, epoch_loss

# %%
# Evaluation function
def evaluate(model, criterion, valid_dataloader):
    model.eval()
    total_acc, total_count = 0, 0
    losses = []
    
    with torch.no_grad():
        for idx, (inputs, labels) in enumerate(valid_dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Predicting the outputs
            predictions = model(inputs)
            
            # Compute loss using criterion
            loss = criterion(predictions, labels)
            losses.append(loss.item())
            
            # Compute accuracy and count
            total_acc += (predictions.argmax(1) == labels).sum().item()
            total_count += labels.size(0)
            
    epoch_acc = total_acc/total_count
    epoch_loss = sum(losses)/len(losses)
    return epoch_acc, epoch_loss

# %% [markdown]
# **TRAINING**

# %%
# Count number of classes
num_classes = len(train_data.dataset.classes)

# LeNet model
alexnet_model = AlexNetCls(num_classes)
alexnet_model.to(device)

# Criterion and Optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(alexnet_model.parameters())

# %%
num_epochs = 50
save_model = './model'

os.makedirs(save_model, exist_ok = True)

train_accs, train_losses = [], []
eval_accs, eval_losses = [], []
best_loss_eval = 100

for epoch in range(1, num_epochs + 1):
    # Epoch start time
    epoch_start_time = time.time()
    
    # Training
    train_acc, train_loss = train(
        alexnet_model, optimizer, criterion, train_dataloader, device, epoch
    )
    train_accs.append(train_acc)
    train_losses.append(train_loss)
    
    # Evaluation
    eval_acc, eval_loss = evaluate(
        alexnet_model, criterion, valid_dataloader
    )
    eval_accs.append(eval_acc)
    eval_losses.append(eval_loss)
    
    # Save best model
    if eval_loss < best_loss_eval:
        torch.save(alexnet_model.state_dict(), save_model + '/alexnet_model.pt')
    
    # Print loss, acc and epoch
    print('-' * 60)
    print(
        '| End of epoch {:3d} | Time : {:5.2f}s | Train Accuracy {:8.3f} | Train Loss {:8.3f}'
        '| Valid Accuracy {:8.3f} | Valid Loss {:8.3f} '.format(
            epoch, time.time() - epoch_start_time, train_acc, train_loss, eval_acc, eval_loss
        )
    )
    print('-' * 60)
    
    # Load best model
    alexnet_model.load_state_dict(torch.load(save_model + '/alexnet_model.pt'))
    alexnet_model.eval()
# Out:
# | epoch   1 |    50/  211 batches | accuracy    0.888
# | epoch   1 |   100/  211 batches | accuracy    0.970
# | epoch   1 |   150/  211 batches | accuracy    0.976
# | epoch   1 |   200/  211 batches | accuracy    0.980
# ------------------------------------------------------------
# | End of epoch   1 | Time : 14.05s | Train Accuracy    0.974 | Train Loss    0.151| Valid Accuracy    0.983 | Valid Loss    0.060
# ------------------------------------------------------------
# | epoch   2 |    50/  211 batches | accuracy    0.982
# | epoch   2 |   100/  211 batches | accuracy    0.983
# | epoch   2 |   150/  211 batches | accuracy    0.984
# | epoch   2 |   200/  211 batches | accuracy    0.985
# ------------------------------------------------------------
# | End of epoch   2 | Time : 13.40s | Train Accuracy    0.985 | Train Loss    0.054| Valid Accuracy    0.988 | Valid Loss    0.041
# ------------------------------------------------------------
# | epoch   3 |    50/  211 batches | accuracy    0.989
# | epoch   3 |   100/  211 batches | accuracy    0.988
# | epoch   3 |   150/  211 batches | accuracy    0.988
# | epoch   3 |   200/  211 batches | accuracy    0.989
# ------------------------------------------------------------
# | End of epoch   3 | Time : 13.35s | Train Accuracy    0.991 | Train Loss    0.039| Valid Accuracy    0.988 | Valid Loss    0.048
# ------------------------------------------------------------
# | epoch   4 |    50/  211 batches | accuracy    0.991
# | epoch   4 |   100/  211 batches | accuracy    0.990
# | epoch   4 |   150/  211 batches | accuracy    0.991
# | epoch   4 |   200/  211 batches | accuracy    0.989
# ------------------------------------------------------------
# | End of epoch   4 | Time : 13.49s | Train Accuracy    0.991 | Train Loss    0.032| Valid Accuracy    0.991 | Valid Loss    0.036
# ------------------------------------------------------------
# | epoch   5 |    50/  211 batches | accuracy    0.992
# | epoch   5 |   100/  211 batches | accuracy    0.992
# | epoch   5 |   150/  211 batches | accuracy    0.992
# | epoch   5 |   200/  211 batches | accuracy    0.993
# ------------------------------------------------------------
# | End of epoch   5 | Time : 13.47s | Train Accuracy    0.995 | Train Loss    0.025| Valid Accuracy    0.991 | Valid Loss    0.031
# ------------------------------------------------------------
# | epoch   6 |    50/  211 batches | accuracy    0.994
# | epoch   6 |   100/  211 batches | accuracy    0.993
# | epoch   6 |   150/  211 batches | accuracy    0.992
# | epoch   6 |   200/  211 batches | accuracy    0.992
# ------------------------------------------------------------
# | End of epoch   6 | Time : 13.62s | Train Accuracy    0.991 | Train Loss    0.023| Valid Accuracy    0.992 | Valid Loss    0.032
# ------------------------------------------------------------
# | epoch   7 |    50/  211 batches | accuracy    0.995
# | epoch   7 |   100/  211 batches | accuracy    0.996
# | epoch   7 |   150/  211 batches | accuracy    0.994
# | epoch   7 |   200/  211 batches | accuracy    0.995
# ------------------------------------------------------------
# | End of epoch   7 | Time : 13.30s | Train Accuracy    0.993 | Train Loss    0.017| Valid Accuracy    0.992 | Valid Loss    0.034
# ------------------------------------------------------------
# | epoch   8 |    50/  211 batches | accuracy    0.995
# | epoch   8 |   100/  211 batches | accuracy    0.994
# | epoch   8 |   150/  211 batches | accuracy    0.995
# | epoch   8 |   200/  211 batches | accuracy    0.994
# ------------------------------------------------------------
# | End of epoch   8 | Time : 13.42s | Train Accuracy    0.996 | Train Loss    0.017| Valid Accuracy    0.993 | Valid Loss    0.035
# ------------------------------------------------------------
# | epoch   9 |    50/  211 batches | accuracy    0.995
# | epoch   9 |   100/  211 batches | accuracy    0.996
# | epoch   9 |   150/  211 batches | accuracy    0.995
# | epoch   9 |   200/  211 batches | accuracy    0.996
# ------------------------------------------------------------
# | End of epoch   9 | Time : 13.40s | Train Accuracy    0.996 | Train Loss    0.014| Valid Accuracy    0.992 | Valid Loss    0.039
# ------------------------------------------------------------
# | epoch  10 |    50/  211 batches | accuracy    0.997
# | epoch  10 |   100/  211 batches | accuracy    0.997
# | epoch  10 |   150/  211 batches | accuracy    0.997
# | epoch  10 |   200/  211 batches | accuracy    0.997
# ------------------------------------------------------------
# | End of epoch  10 | Time : 13.51s | Train Accuracy    0.996 | Train Loss    0.011| Valid Accuracy    0.993 | Valid Loss    0.036
# ------------------------------------------------------------
# | epoch  11 |    50/  211 batches | accuracy    0.997
# | epoch  11 |   100/  211 batches | accuracy    0.997
# | epoch  11 |   150/  211 batches | accuracy    0.996
# | epoch  11 |   200/  211 batches | accuracy    0.997
# ------------------------------------------------------------
# | End of epoch  11 | Time : 13.46s | Train Accuracy    0.996 | Train Loss    0.011| Valid Accuracy    0.993 | Valid Loss    0.035
# ------------------------------------------------------------
# | epoch  12 |    50/  211 batches | accuracy    0.997
# | epoch  12 |   100/  211 batches | accuracy    0.997
# | epoch  12 |   150/  211 batches | accuracy    0.997
# | epoch  12 |   200/  211 batches | accuracy    0.997
# ------------------------------------------------------------
# | End of epoch  12 | Time : 13.42s | Train Accuracy    0.996 | Train Loss    0.008| Valid Accuracy    0.993 | Valid Loss    0.034
# ------------------------------------------------------------
# | epoch  13 |    50/  211 batches | accuracy    0.998
# | epoch  13 |   100/  211 batches | accuracy    0.997
# | epoch  13 |   150/  211 batches | accuracy    0.998
# | epoch  13 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  13 | Time : 13.47s | Train Accuracy    0.996 | Train Loss    0.008| Valid Accuracy    0.993 | Valid Loss    0.037
# ------------------------------------------------------------
# | epoch  14 |    50/  211 batches | accuracy    0.998
# | epoch  14 |   100/  211 batches | accuracy    0.998
# | epoch  14 |   150/  211 batches | accuracy    0.997
# | epoch  14 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  14 | Time : 13.40s | Train Accuracy    0.997 | Train Loss    0.008| Valid Accuracy    0.993 | Valid Loss    0.040
# ------------------------------------------------------------
# | epoch  15 |    50/  211 batches | accuracy    0.997
# | epoch  15 |   100/  211 batches | accuracy    0.998
# | epoch  15 |   150/  211 batches | accuracy    0.998
# | epoch  15 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  15 | Time : 13.45s | Train Accuracy    0.997 | Train Loss    0.007| Valid Accuracy    0.994 | Valid Loss    0.032
# ------------------------------------------------------------
# | epoch  16 |    50/  211 batches | accuracy    0.998
# | epoch  16 |   100/  211 batches | accuracy    0.998
# | epoch  16 |   150/  211 batches | accuracy    0.997
# | epoch  16 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  16 | Time : 13.36s | Train Accuracy    0.998 | Train Loss    0.007| Valid Accuracy    0.994 | Valid Loss    0.032
# ------------------------------------------------------------
# | epoch  17 |    50/  211 batches | accuracy    0.998
# | epoch  17 |   100/  211 batches | accuracy    0.998
# | epoch  17 |   150/  211 batches | accuracy    0.998
# | epoch  17 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  17 | Time : 13.43s | Train Accuracy    0.996 | Train Loss    0.007| Valid Accuracy    0.992 | Valid Loss    0.035
# ------------------------------------------------------------
# | epoch  18 |    50/  211 batches | accuracy    0.998
# | epoch  18 |   100/  211 batches | accuracy    0.999
# | epoch  18 |   150/  211 batches | accuracy    0.998
# | epoch  18 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  18 | Time : 13.54s | Train Accuracy    0.998 | Train Loss    0.006| Valid Accuracy    0.994 | Valid Loss    0.039
# ------------------------------------------------------------
# | epoch  19 |    50/  211 batches | accuracy    0.999
# | epoch  19 |   100/  211 batches | accuracy    0.999
# | epoch  19 |   150/  211 batches | accuracy    0.998
# | epoch  19 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  19 | Time : 13.54s | Train Accuracy    0.998 | Train Loss    0.004| Valid Accuracy    0.992 | Valid Loss    0.039
# ------------------------------------------------------------
# | epoch  20 |    50/  211 batches | accuracy    0.999
# | epoch  20 |   100/  211 batches | accuracy    0.999
# | epoch  20 |   150/  211 batches | accuracy    0.999
# | epoch  20 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  20 | Time : 13.70s | Train Accuracy    0.999 | Train Loss    0.005| Valid Accuracy    0.995 | Valid Loss    0.034
# ------------------------------------------------------------
# | epoch  21 |    50/  211 batches | accuracy    0.999
# | epoch  21 |   100/  211 batches | accuracy    0.999
# | epoch  21 |   150/  211 batches | accuracy    0.999
# | epoch  21 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  21 | Time : 13.46s | Train Accuracy    0.997 | Train Loss    0.005| Valid Accuracy    0.993 | Valid Loss    0.038
# ------------------------------------------------------------
# | epoch  22 |    50/  211 batches | accuracy    0.999
# | epoch  22 |   100/  211 batches | accuracy    0.999
# | epoch  22 |   150/  211 batches | accuracy    0.998
# | epoch  22 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  22 | Time : 13.46s | Train Accuracy    0.999 | Train Loss    0.006| Valid Accuracy    0.993 | Valid Loss    0.045
# ------------------------------------------------------------
# | epoch  23 |    50/  211 batches | accuracy    0.998
# | epoch  23 |   100/  211 batches | accuracy    0.999
# | epoch  23 |   150/  211 batches | accuracy    0.998
# | epoch  23 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  23 | Time : 13.46s | Train Accuracy    0.998 | Train Loss    0.004| Valid Accuracy    0.994 | Valid Loss    0.031
# ------------------------------------------------------------
# | epoch  24 |    50/  211 batches | accuracy    0.999
# | epoch  24 |   100/  211 batches | accuracy    0.998
# | epoch  24 |   150/  211 batches | accuracy    0.999
# | epoch  24 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  24 | Time : 13.42s | Train Accuracy    0.997 | Train Loss    0.005| Valid Accuracy    0.994 | Valid Loss    0.038
# ------------------------------------------------------------
# | epoch  25 |    50/  211 batches | accuracy    0.998
# | epoch  25 |   100/  211 batches | accuracy    0.999
# | epoch  25 |   150/  211 batches | accuracy    0.999
# | epoch  25 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  25 | Time : 13.52s | Train Accuracy    1.000 | Train Loss    0.004| Valid Accuracy    0.993 | Valid Loss    0.048
# ------------------------------------------------------------
# | epoch  26 |    50/  211 batches | accuracy    0.999
# | epoch  26 |   100/  211 batches | accuracy    0.999
# | epoch  26 |   150/  211 batches | accuracy    0.999
# | epoch  26 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  26 | Time : 13.42s | Train Accuracy    0.998 | Train Loss    0.004| Valid Accuracy    0.994 | Valid Loss    0.041
# ------------------------------------------------------------
# | epoch  27 |    50/  211 batches | accuracy    0.999
# | epoch  27 |   100/  211 batches | accuracy    0.999
# | epoch  27 |   150/  211 batches | accuracy    0.999
# | epoch  27 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  27 | Time : 13.56s | Train Accuracy    0.998 | Train Loss    0.004| Valid Accuracy    0.993 | Valid Loss    0.042
# ------------------------------------------------------------
# | epoch  28 |    50/  211 batches | accuracy    0.999
# | epoch  28 |   100/  211 batches | accuracy    0.999
# | epoch  28 |   150/  211 batches | accuracy    1.000
# | epoch  28 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  28 | Time : 13.51s | Train Accuracy    0.999 | Train Loss    0.002| Valid Accuracy    0.994 | Valid Loss    0.041
# ------------------------------------------------------------
# | epoch  29 |    50/  211 batches | accuracy    0.999
# | epoch  29 |   100/  211 batches | accuracy    0.999
# | epoch  29 |   150/  211 batches | accuracy    0.999
# | epoch  29 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  29 | Time : 13.59s | Train Accuracy    0.998 | Train Loss    0.003| Valid Accuracy    0.994 | Valid Loss    0.044
# ------------------------------------------------------------
# | epoch  30 |    50/  211 batches | accuracy    0.999
# | epoch  30 |   100/  211 batches | accuracy    0.999
# | epoch  30 |   150/  211 batches | accuracy    0.999
# | epoch  30 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  30 | Time : 13.60s | Train Accuracy    0.999 | Train Loss    0.003| Valid Accuracy    0.995 | Valid Loss    0.036
# ------------------------------------------------------------
# | epoch  31 |    50/  211 batches | accuracy    0.999
# | epoch  31 |   100/  211 batches | accuracy    0.999
# | epoch  31 |   150/  211 batches | accuracy    0.999
# | epoch  31 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  31 | Time : 13.48s | Train Accuracy    1.000 | Train Loss    0.004| Valid Accuracy    0.994 | Valid Loss    0.040
# ------------------------------------------------------------
# | epoch  32 |    50/  211 batches | accuracy    0.999
# | epoch  32 |   100/  211 batches | accuracy    0.999
# | epoch  32 |   150/  211 batches | accuracy    0.999
# | epoch  32 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  32 | Time : 13.61s | Train Accuracy    0.999 | Train Loss    0.003| Valid Accuracy    0.994 | Valid Loss    0.044
# ------------------------------------------------------------
# | epoch  33 |    50/  211 batches | accuracy    0.999
# | epoch  33 |   100/  211 batches | accuracy    1.000
# | epoch  33 |   150/  211 batches | accuracy    0.999
# | epoch  33 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  33 | Time : 13.51s | Train Accuracy    1.000 | Train Loss    0.003| Valid Accuracy    0.993 | Valid Loss    0.045
# ------------------------------------------------------------
# | epoch  34 |    50/  211 batches | accuracy    1.000
# | epoch  34 |   100/  211 batches | accuracy    0.999
# | epoch  34 |   150/  211 batches | accuracy    1.000
# | epoch  34 |   200/  211 batches | accuracy    1.000
# ------------------------------------------------------------
# | End of epoch  34 | Time : 13.56s | Train Accuracy    0.998 | Train Loss    0.003| Valid Accuracy    0.994 | Valid Loss    0.042
# ------------------------------------------------------------
# | epoch  35 |    50/  211 batches | accuracy    0.999
# | epoch  35 |   100/  211 batches | accuracy    0.999
# | epoch  35 |   150/  211 batches | accuracy    0.999
# | epoch  35 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  35 | Time : 13.49s | Train Accuracy    0.999 | Train Loss    0.003| Valid Accuracy    0.995 | Valid Loss    0.049
# ------------------------------------------------------------
# | epoch  36 |    50/  211 batches | accuracy    1.000
# | epoch  36 |   100/  211 batches | accuracy    0.999
# | epoch  36 |   150/  211 batches | accuracy    0.999
# | epoch  36 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  36 | Time : 13.63s | Train Accuracy    1.000 | Train Loss    0.003| Valid Accuracy    0.993 | Valid Loss    0.051
# ------------------------------------------------------------
# | epoch  37 |    50/  211 batches | accuracy    0.999
# | epoch  37 |   100/  211 batches | accuracy    0.999
# | epoch  37 |   150/  211 batches | accuracy    0.999
# | epoch  37 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  37 | Time : 13.68s | Train Accuracy    1.000 | Train Loss    0.003| Valid Accuracy    0.994 | Valid Loss    0.045
# ------------------------------------------------------------
# | epoch  38 |    50/  211 batches | accuracy    0.999
# | epoch  38 |   100/  211 batches | accuracy    0.999
# | epoch  38 |   150/  211 batches | accuracy    1.000
# | epoch  38 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  38 | Time : 13.47s | Train Accuracy    0.999 | Train Loss    0.002| Valid Accuracy    0.994 | Valid Loss    0.048
# ------------------------------------------------------------
# | epoch  39 |    50/  211 batches | accuracy    0.999
# | epoch  39 |   100/  211 batches | accuracy    0.999
# | epoch  39 |   150/  211 batches | accuracy    0.999
# | epoch  39 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  39 | Time : 13.52s | Train Accuracy    1.000 | Train Loss    0.002| Valid Accuracy    0.995 | Valid Loss    0.052
# ------------------------------------------------------------
# | epoch  40 |    50/  211 batches | accuracy    1.000
# | epoch  40 |   100/  211 batches | accuracy    0.999
# | epoch  40 |   150/  211 batches | accuracy    0.999
# | epoch  40 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  40 | Time : 13.47s | Train Accuracy    1.000 | Train Loss    0.002| Valid Accuracy    0.994 | Valid Loss    0.054
# ------------------------------------------------------------
# | epoch  41 |    50/  211 batches | accuracy    0.999
# | epoch  41 |   100/  211 batches | accuracy    0.999
# | epoch  41 |   150/  211 batches | accuracy    0.999
# | epoch  41 |   200/  211 batches | accuracy    0.998
# ------------------------------------------------------------
# | End of epoch  41 | Time : 13.43s | Train Accuracy    1.000 | Train Loss    0.003| Valid Accuracy    0.994 | Valid Loss    0.048
# ------------------------------------------------------------
# | epoch  42 |    50/  211 batches | accuracy    1.000
# | epoch  42 |   100/  211 batches | accuracy    0.999
# | epoch  42 |   150/  211 batches | accuracy    0.999
# | epoch  42 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  42 | Time : 13.51s | Train Accuracy    0.999 | Train Loss    0.003| Valid Accuracy    0.994 | Valid Loss    0.059
# ------------------------------------------------------------
# | epoch  43 |    50/  211 batches | accuracy    1.000
# | epoch  43 |   100/  211 batches | accuracy    0.999
# | epoch  43 |   150/  211 batches | accuracy    0.999
# | epoch  43 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  43 | Time : 13.64s | Train Accuracy    1.000 | Train Loss    0.003| Valid Accuracy    0.994 | Valid Loss    0.051
# ------------------------------------------------------------
# | epoch  44 |    50/  211 batches | accuracy    0.999
# | epoch  44 |   100/  211 batches | accuracy    0.999
# | epoch  44 |   150/  211 batches | accuracy    0.999
# | epoch  44 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  44 | Time : 13.34s | Train Accuracy    0.999 | Train Loss    0.002| Valid Accuracy    0.993 | Valid Loss    0.061
# ------------------------------------------------------------
# | epoch  45 |    50/  211 batches | accuracy    0.999
# | epoch  45 |   100/  211 batches | accuracy    1.000
# | epoch  45 |   150/  211 batches | accuracy    1.000
# | epoch  45 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  45 | Time : 13.37s | Train Accuracy    1.000 | Train Loss    0.003| Valid Accuracy    0.994 | Valid Loss    0.055
# ------------------------------------------------------------
# | epoch  46 |    50/  211 batches | accuracy    1.000
# | epoch  46 |   100/  211 batches | accuracy    1.000
# | epoch  46 |   150/  211 batches | accuracy    1.000
# | epoch  46 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  46 | Time : 13.46s | Train Accuracy    0.999 | Train Loss    0.002| Valid Accuracy    0.993 | Valid Loss    0.057
# ------------------------------------------------------------
# | epoch  47 |    50/  211 batches | accuracy    0.999
# | epoch  47 |   100/  211 batches | accuracy    0.999
# | epoch  47 |   150/  211 batches | accuracy    0.999
# | epoch  47 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  47 | Time : 13.42s | Train Accuracy    0.999 | Train Loss    0.003| Valid Accuracy    0.994 | Valid Loss    0.062
# ------------------------------------------------------------
# | epoch  48 |    50/  211 batches | accuracy    1.000
# | epoch  48 |   100/  211 batches | accuracy    0.999
# | epoch  48 |   150/  211 batches | accuracy    0.999
# | epoch  48 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  48 | Time : 13.51s | Train Accuracy    1.000 | Train Loss    0.002| Valid Accuracy    0.994 | Valid Loss    0.053
# ------------------------------------------------------------
# | epoch  49 |    50/  211 batches | accuracy    0.999
# | epoch  49 |   100/  211 batches | accuracy    1.000
# | epoch  49 |   150/  211 batches | accuracy    0.999
# | epoch  49 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  49 | Time : 13.45s | Train Accuracy    0.999 | Train Loss    0.003| Valid Accuracy    0.995 | Valid Loss    0.052
# ------------------------------------------------------------
# | epoch  50 |    50/  211 batches | accuracy    1.000
# | epoch  50 |   100/  211 batches | accuracy    1.000
# | epoch  50 |   150/  211 batches | accuracy    1.000
# | epoch  50 |   200/  211 batches | accuracy    0.999
# ------------------------------------------------------------
# | End of epoch  50 | Time : 13.53s | Train Accuracy    0.999 | Train Loss    0.002| Valid Accuracy    0.995 | Valid Loss    0.050
# ------------------------------------------------------------

# %%
# Plotting the training and validating losses
fig, ax = plt.subplots(1, 2, figsize = (12,5))

# Training losses
ax[0].plot(train_losses, color = 'green')
ax[0].set_title('Training Loss')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')

# Validating losses
ax[1].plot(eval_losses, color = 'orange')
ax[1].set_title('Validating Loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss') 

plt.show()

# %% [markdown]
# **EVALUATION**

# %%
test_data.transform = test_transforms
test_dataloader = data.DataLoader(
    test_data,
    batch_size = batch_size
)
test_acc, test_loss = evaluate(alexnet_model, criterion, test_dataloader)
test_acc, test_loss
# Out:
# (0.9924, 0.055289380435539034)
